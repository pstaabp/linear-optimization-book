# %%
using CairoMakie
CairoMakie.activate!()
Makie.inline!(true)
# Out:
# true

# %%
xs = ys = LinRange(-1,20,20)
fig, ax = contour(xs, ys, [x + y for x in xs, y in ys], levels = [15])
contour!(ax, xs, ys, [2x+3y for x in xs, y in ys], levels = [38])
contour!(ax, xs, ys, [4x+y for x in xs, y in ys], levels = [56])
contour!(ax, xs, ys, [x+5y for x in xs, y in ys], levels = [62])
fig

# %%
xs = ys = LinRange(-1,20,20)
fig, ax = contour(xs, ys, [-3x + 2y for x in xs, y in ys], levels = [-24])
contour!(xs, ys, [5x-4y for x in xs, y in ys], levels=[-30])
contour!(xs, ys, [x+y for x in xs, y in ys], levels= [10])
fig
